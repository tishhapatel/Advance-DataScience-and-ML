# %%
import pandas as pd
from io import StringIO

# Read ARFF file
with open("WISDM_ar_v1.1_transformed.arff", "r") as f:
    lines = f.readlines()

# Extract attribute names
attributes = []
data_start = 0

for i, line in enumerate(lines):
    if line.lower().startswith("@attribute"):
        attributes.append(line.split()[1])
    if line.lower().strip() == "@data":
        data_start = i + 1
        break

# Extract data part
data = lines[data_start:]

# Convert to DataFrame
data_str = "".join(data)
df = pd.read_csv(StringIO(data_str), header=None)
df.columns = attributes

# %%
df.to_csv("WISDM_ar_v1.1_transformed.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("WISDM_ar_v1.1_transformed.csv")

df.head()
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5418 entries, 0 to 5417
# Data columns (total 46 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   "UNIQUE_ID"  5418 non-null   int64
#  1   "user"       5418 non-null   int64
#  2   "X0"         5418 non-null   float64
#  3   "X1"         5418 non-null   float64
#  4   "X2"         5418 non-null   float64
#  5   "X3"         5418 non-null   float64
#  6   "X4"         5418 non-null   float64
#  7   "X5"         5418 non-null   float64
#  8   "X6"         5418 non-null   float64
#  9   "X7"         5418 non-null   float64
#  10  "X8"         5418 non-null   float64
#  11  "X9"         5418 non-null   float64
#  12  "Y0"         5418 non-null   float64
#  13  "Y1"         5418 non-null   float64
#  14  "Y2"         5418 non-null   float64
#  15  "Y3"         5418 non-null   float64
#  16  "Y4"         5418 non-null   float64
#  17  "Y5"         5418 non-null   float64
# ...

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.replace('"', '').str.strip()

# %%
df.columns
# Out:
# Index(['UNIQUE_ID', 'user', 'X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7',
#        'X8', 'X9', 'Y0', 'Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9',
#        'Z0', 'Z1', 'Z2', 'Z3', 'Z4', 'Z5', 'Z6', 'Z7', 'Z8', 'Z9', 'XAVG',
#        'YAVG', 'ZAVG', 'XPEAK', 'YPEAK', 'ZPEAK', 'XABSOLDEV', 'YABSOLDEV',
#        'ZABSOLDEV', 'XSTANDDEV', 'YSTANDDEV', 'ZSTANDDEV', 'RESULTANT',
#        'class{'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.countplot(x='class{', data=df)
plt.xticks(rotation=45)
plt.title("Target Variable (Activity) Distribution")
plt.show()

# %%
class_percent = df['class{'].value_counts(normalize=True) * 100
print(class_percent)
# Out:
# class{
# Walking       38.409007
# Jogging       29.992617
# Upstairs      11.664821
# Downstairs     9.745293
# Sitting        5.647841
# Standing       4.540421
# Name: proportion, dtype: float64

# %%
df.rename(columns={'class{': 'activity'}, inplace=True)

# %%
sns.countplot(x='activity', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.countplot(x='activity', data=df)
plt.xticks(rotation=45)
plt.title("Target Variable Distribution")
plt.show()

# %%
sns.boxplot(y=df['XAVG'])
plt.title("Outlier Detection using Boxplot")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

import numpy as np

X = X.replace('?', np.nan)
X = X.apply(pd.to_numeric)
X = X.fillna(X.mean())
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(sensor_cols.corr(), cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Sensor Features")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['activity'] = le.fit_transform(df['activity'])

# %%
X = df.drop(['activity', 'UNIQUE_ID', 'user'], axis=1)
y = df['activity']

# %%
(X == '?').sum().sort_values(ascending=False)
# Out:
# XPEAK        381
# YPEAK        131
# ZPEAK        103
# X3             0
# X4             0
# X5             0
# X6             0
# X7             0
# X0             0
# X1             0
# X2             0
# Y0             0
# X9             0
# X8             0
# Y1             0
# Y5             0
# Y2             0
# Y3             0
# Y4             0
# Y9             0
# Z0             0
# Z1             0
# Z2             0
# Z3             0
# Y6             0
# Y7             0
# Y8             0
# Z6             0
# Z5             0
# Z4             0
# Z7             0
# XAVG           0
# Z9             0
# ZAVG           0
# Z8             0
# YAVG           0
# XABSOLDEV      0
# YABSOLDEV      0
# ZABSOLDEV      0
# XSTANDDEV      0
# YSTANDDEV      0
# ZSTANDDEV      0
# RESULTANT      0
# dtype: int64

# %%
import numpy as np

X = X.replace('?', np.nan)

# %%
X = X.apply(pd.to_numeric, errors='coerce')

# %%
X = X.fillna(X.mean())

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
plt.figure(figsize=(6,4))
df['XAVG'].hist(bins=50)
plt.title("Distribution of XAVG Feature")
plt.xlabel("XAVG")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.kdeplot(df['XAVG'], label='XAVG')
sns.kdeplot(df['YAVG'], label='YAVG')
sns.kdeplot(df['ZAVG'], label='ZAVG')
plt.legend()
plt.title("Distribution of X, Y, Z Average Signals")
plt.show()
# Out:
# C:\Users\Tisha Patel\AppData\Local\Temp\ipykernel_13148\275372025.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df['XAVG'], label='XAVG')

# %%
sample_df = df[['XAVG', 'YAVG', 'ZAVG', 'activity']].sample(500)
sns.pairplot(sample_df, hue='activity')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8874538745387454
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.54      0.63       106
#            1       0.96      0.98      0.97       325
#            2       1.00      0.95      0.97        61
#            3       0.96      0.96      0.96        49
#            4       0.77      0.62      0.69       127
#            5       0.86      0.96      0.91       416
#
#     accuracy                           0.89      1084
#    macro avg       0.88      0.84      0.86      1084
# weighted avg       0.88      0.89      0.88      1084

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', C=1, gamma='scale')
svm.fit(X_train, y_train)
# Out:
# SVC(C=1)

# %%
svm_pred = svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("SVM Accuracy:", accuracy_score(y_test, svm_pred))
print("\nSVM Classification Report:\n")
print(classification_report(y_test, svm_pred))
# Out:
# SVM Accuracy: 0.794280442804428
#
# SVM Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.14      0.22       106
#            1       0.96      0.99      0.98       325
#            2       0.77      0.98      0.86        61
#            3       0.97      0.63      0.77        49
#            4       0.57      0.28      0.37       127
#            5       0.72      0.95      0.82       416
#
#     accuracy                           0.79      1084
#    macro avg       0.75      0.66      0.67      1084
# weighted avg       0.77      0.79      0.76      1084

# %%
rf_pred = rf.predict(X_test)
svm_pred = svm.predict(X_test)

# %%
from sklearn.metrics import precision_score

rf_precision = precision_score(y_test, rf_pred, average='macro')
svm_precision = precision_score(y_test, svm_pred, average='macro')

print("Random Forest Precision:", rf_precision)
print("SVM Precision:", svm_precision)
# Out:
# Random Forest Precision: 0.8844372314107837
# SVM Precision: 0.752459119816407
